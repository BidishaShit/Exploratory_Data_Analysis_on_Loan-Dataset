# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Loading the dataset
df = pd.read_csv("loan.csv")
print(df)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#describe the dataset
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.head(2)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N

# %%
#checking if there is any missing values
df[df.isna().any(axis=1)]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 11   LP001027    Male     Yes          2      Graduate           NaN
# 16   LP001034    Male      No          1  Not Graduate            No
# 19   LP001041    Male     Yes          0      Graduate           NaN
# 23   LP001050     NaN     Yes          2  Not Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 592  LP002933     NaN      No         3+      Graduate           Yes
# 597  LP002943    Male      No        NaN      Graduate            No
# 600  LP002949  Female      No         3+      Graduate           NaN
# 601  LP002950    Male     Yes          0  Not Graduate           NaN
# 605  LP002960    Male     Yes          0  Not Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#drop ta missing values
df.dropna(inplace=True)

# %%
#checking if there is any missing values left
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area, Loan_Status]
# Index: []

# %%
#visualizing relationship between applicant income and loan amount with scatter plot
x=df["ApplicantIncome"].to_numpy()
y=df["LoanAmount"].to_numpy()
df1=plt.scatter(x,y)
plt.title("relation visualization with scatter plot")
plt.xlabel("Applicant Income")
plt.ylabel("Loan Amount")
# Out:
# Text(0, 0.5, 'Loan Amount')

# %%
#correlation
df.loc[:,'ApplicantIncome'].corr(df.loc[:,'LoanAmount'],method='pearson',min_periods=1)
# Out:
# 0.495309586086553

# %%
#visualizing relationship between applicant income and loan amount with box plot
boxplot=df.boxplot(column=['ApplicantIncome','LoanAmount'])

# %%
#unique values of a categorical variable.
df.LoanAmount.unique()
# Out:
# array([128.,  66., 120., 141., 267.,  95., 158., 168., 349.,  70., 200.,
#        114.,  17., 125.,  76., 133., 104., 315., 116., 191., 122., 110.,
#         35.,  74., 106., 320., 144., 184.,  80.,  47., 134.,  44., 100.,
#        112., 286.,  97.,  96., 135., 180.,  99., 165., 258., 126., 312.,
#        136., 172.,  81., 187., 113., 176., 111., 167.,  50., 210., 175.,
#        131., 188.,  25., 137., 115., 151., 225., 216.,  94., 185., 154.,
#        259., 194., 160., 102., 290.,  84.,  88., 242., 129.,  30., 118.,
#        152., 244., 600., 255.,  98., 275., 121.,  75.,  63.,  87., 101.,
#        495.,  73., 260., 108.,  48., 164., 170.,  83.,  90., 166., 124.,
#         55.,  59., 127., 214., 240., 130.,  60., 280., 140., 155., 123.,
#        201., 138., 279., 192., 304., 150., 207., 436.,  78.,  54.,  89.,
#        139.,  93., 132., 480.,  56., 300., 376.,  67., 117.,  71., 173.,
#         46., 228., 308., 105., 236., 570., 380., 296., 156., 109., 103.,
# ...

# %%
#create contingency table
data_crosstab=pd.crosstab(df['Loan_Status'], df['ApplicantIncome'])
print(data_crosstab)
# Out:
# ApplicantIncome  150    645    1000   1025   1299   1378   1442   1500   \
# Loan_Status
# N                    1      0      1      0      0      1      1      1
# Y                    0      1      0      1      1      0      0      0
#
# ApplicantIncome  1538   1600   ...  18165  18333  19484  19730  20233  33846  \
# Loan_Status                    ...
# N                    0      1  ...      0      1      0      1      1      1
# Y                    1      0  ...      1      0      1      0      0      0
#
# ApplicantIncome  37719  39147  39999  81000
# Loan_Status
# N                    0      0      0      1
# Y                    1      1      1      0
#
# [2 rows x 405 columns]

# %%
#chi square = (observed-expected)^2/expected

# %%
#statistical test of the independence between them.
from scipy import stats
chi2,p,dof,expected=stats.chi2_contingency(data_crosstab)
print("Chi-square statistic: ",chi2)
print("p-value: ",p)
# Out:
# Chi-square statistic:  399.62785504954184
# p-value:  0.5520698883903832

# %%
#the subset of rows based on two or more criteria
loan_subset1 =  df.loc[(df["Education"] == "Graduate")& (df['ApplicantIncome']> 4000)]
loan_subset1.head(2)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 1  LP001003   Male     Yes          1  Graduate            No
# 4  LP001008   Male      No          0  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1             4583             1508.0       128.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 1             1.0         Rural           N
# 4             1.0         Urban           Y

# %%
#descriptive statistics
loan_subset1.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       192.000000         192.000000  192.000000        192.000000
# mean       8565.265625        1267.229167  187.625000        343.562500
# std        7714.197207        2113.425814  101.816666         53.656814
# min        4006.000000           0.000000   26.000000         84.000000
# 25%        4887.500000           0.000000  124.750000        360.000000
# 50%        6191.500000           0.000000  163.000000        360.000000
# 75%        9372.000000        2061.250000  216.750000        360.000000
# max       81000.000000       11300.000000  600.000000        480.000000
#
#        Credit_History
# count      192.000000
# mean         0.869792
# std          0.337412
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
#the subset of rows based on two or more criteria
df_row1=df.iloc[1:11,[4,9]]
df_row1.describe()
# Out:
#        Loan_Amount_Term
# count              10.0
# mean              360.0
# std                 0.0
# min               360.0
# 25%               360.0
# 50%               360.0
# 75%               360.0
# max               360.0

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
# 5             5417             4196.0       267.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status']

# %%
#character to integer
df=pd.get_dummies(df,columns=['Gender'],dtype=int)
df.head()
# Out:
#     Loan_ID Married Dependents     Education Self_Employed  ApplicantIncome  \
# 1  LP001003     Yes          1      Graduate            No             4583
# 2  LP001005     Yes          0      Graduate           Yes             3000
# 3  LP001006     Yes          0  Not Graduate            No             2583
# 4  LP001008      No          0      Graduate            No             6000
# 5  LP001011     Yes          2      Graduate           Yes             5417
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
# 5             4196.0       267.0             360.0             1.0
#
#   Property_Area Loan_Status  Gender_Female  Gender_Male
# ...

# %%
df.head(5)
# Out:
#     Loan_ID Married Dependents     Education Self_Employed  ApplicantIncome  \
# 1  LP001003     Yes          1      Graduate            No             4583
# 2  LP001005     Yes          0      Graduate           Yes             3000
# 3  LP001006     Yes          0  Not Graduate            No             2583
# 4  LP001008      No          0      Graduate            No             6000
# 5  LP001011     Yes          2      Graduate           Yes             5417
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
# 5             4196.0       267.0             360.0             1.0
#
#   Property_Area Loan_Status  Gender_Female  Gender_Male
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Loan_ID', 'Married', 'Dependents', 'Education', 'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status', 'Gender_Female', 'Gender_Male']

# %%
#the subset of rows based on two or more criteria
Loan_subset = df[['Gender_Male','ApplicantIncome']]
Loan_subset.head()
# Out:
#    Gender_Male  ApplicantIncome
# 1            1             4583
# 2            1             3000
# 3            1             2583
# 4            1             6000
# 5            1             5417

# %%
#difference between the means of two subsets
from scipy.stats import ttest_1samp
stats.ttest_1samp(Loan_subset,90)
# Out:
# TtestResult(statistic=array([-5089.4993979 ,    20.38593775]), pvalue=array([0.0000000e+00, 5.6728521e-67]), df=array([479, 479]))

# %%
df=pd.get_dummies(df,columns=['Married','Property_Area'],dtype=int)

# %%
print(df.head())
# Out:
#     Loan_ID Dependents     Education Self_Employed  ApplicantIncome  \
# 1  LP001003          1      Graduate            No             4583
# 2  LP001005          0      Graduate           Yes             3000
# 3  LP001006          0  Not Graduate            No             2583
# 4  LP001008          0      Graduate            No             6000
# 5  LP001011          2      Graduate           Yes             5417
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
# 5             4196.0       267.0             360.0             1.0
#
#   Loan_Status  Gender_Female  Gender_Male  Married_No  Married_Yes  \
# 1           N              0            1           0            1
# ...

# %%
df=pd.get_dummies(df,columns=['Education','Self_Employed'],dtype=int)
df=pd.get_dummies(df,columns=['Loan_Status'],dtype=int)

# %%
df.head()
# Out:
#     Loan_ID Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 1  LP001003          1             4583             1508.0       128.0
# 2  LP001005          0             3000                0.0        66.0
# 3  LP001006          0             2583             2358.0       120.0
# 4  LP001008          0             6000                0.0       141.0
# 5  LP001011          2             5417             4196.0       267.0
#
#    Loan_Amount_Term  Credit_History  Gender_Female  Gender_Male  Married_No  \
# 1             360.0             1.0              0            1           0
# 2             360.0             1.0              0            1           0
# 3             360.0             1.0              0            1           0
# 4             360.0             1.0              0            1           1
# 5             360.0             1.0              0            1           0
#
#    Married_Yes  Property_Area_Rural  Property_Area_Semiurban  \
# ...

# %%
df=df.drop('Loan_ID', axis=1)

# %%
df=df.drop('Dependents', axis=1)

# %%
df.head()
# Out:
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
# 5             5417             4196.0       267.0             360.0
#
#    Credit_History  Gender_Female  Gender_Male  Married_No  Married_Yes  \
# 1             1.0              0            1           0            1
# 2             1.0              0            1           0            1
# 3             1.0              0            1           0            1
# 4             1.0              0            1           1            0
# 5             1.0              0            1           0            1
#
#    Property_Area_Rural  Property_Area_Semiurban  Property_Area_Urban  \
# ...

# %%
#Create one or more table ,displays summarized information for each group
df2=df.groupby(['ApplicantIncome', 'CoapplicantIncome'])['LoanAmount'].describe()
df2
# Out:
#                                    count   mean  std    min    25%    50%  \
# ApplicantIncome CoapplicantIncome
# 150             1800.0               1.0  135.0  NaN  135.0  135.0  135.0
# 645             3683.0               1.0  113.0  NaN  113.0  113.0  113.0
# 1000            3022.0               1.0  110.0  NaN  110.0  110.0  110.0
# 1025            2773.0               1.0  112.0  NaN  112.0  112.0  112.0
# 1299            1086.0               1.0   17.0  NaN   17.0   17.0   17.0
# ...                                  ...    ...  ...    ...    ...    ...
# 33846           0.0                  1.0  260.0  NaN  260.0  260.0  260.0
# 37719           0.0                  1.0  152.0  NaN  152.0  152.0  152.0
# 39147           4750.0               1.0  120.0  NaN  120.0  120.0  120.0
# 39999           0.0                  1.0  600.0  NaN  600.0  600.0  600.0
# 81000           0.0                  1.0  360.0  NaN  360.0  360.0  360.0
#
# ...

# %%
#Implement a linear regression model and interpret its output.
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression

# %%
x= df.iloc[:,:-2]
y= df.iloc[:,-1]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.05,random_state=0)

# %%
logreg=LogisticRegression()
logreg.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred=logreg.predict(x_test)
print("Accuracy: ",metrics.accuracy_score(y_test,y_pred))
print("Precision: ",metrics.precision_score(y_test,y_pred))
print("Recall: ",metrics.recall_score(y_test,y_pred))
# Out:
# Accuracy:  0.625
# Precision:  0.5909090909090909
# Recall:  1.0

# %%
import numpy as np
from sklearn.metrics import f1_score
#calculate F1 score
f1_score(y_test, y_pred)
# Out:
# 0.7428571428571429

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[ 2,  9],
#        [ 0, 13]], dtype=int64)

# %% [markdown]
# Accuracy = (TP+T)/(P+N)
# Precision(Positive predicted value) = TP/(TP+FP)
# Recall or Sensitivity or True positive rate = TP/(TP +FN) = TP/P
